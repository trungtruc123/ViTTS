# %%
import os
import numpy as np
import pandas as pd
from tqdm import tqdm
from typing import Union, Text,List
from tests import get_test_input_path, get_test_data_path, get_test_output_path

# %%
DATA_PATH = os.path.join(get_test_data_path(),"vispeech")
OUT_PATH = os.path.join(get_test_output_path(), "output_train")

# %%
from IPython.display import Audio, display

display(Audio(os.path.join(DATA_PATH,"wavs/0/09981.wav"), autoplay=True))
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from vitts.utils.config.config_share import BaseDatasetConfig

# %%
dataset_config = BaseDatasetConfig(
    name="vispeech",
    meta_file_train="metadata_dummy.csv",
    path=DATA_PATH,
    language="vi"
)

# %%
dataset_config
# Out:
# BaseDatasetConfig(name='vispeech', path='/home/truc/Documents/ViTTS/tests/data/vispeech', meta_file_train='metadata_dummy.csv', ignored_speakers=None, language='vi', meta_file_val='', meta_file_attn_mask='')

# %%
from vitts.components.vitts.configs.glow_tts_config import GlowTTSConfig

# %%
config_glowtts = GlowTTSConfig(
    batch_size= 32,
    eval_batch_size= 16,
    num_loader_workers= 0,
    num_eval_loader_workers=0,
    run_eval= True,
    test_delay_epochs= -1,
    epochs=2,
    text_cleaner="vi_cleaners",
    use_phonemes= False,
    print_step= 25,
    print_eval= False,
    mixed_precision= True,
    output_path= OUT_PATH,
    datasets=[dataset_config],
    save_step= 1000
)

# %%
config_glowtts
# Out:
# GlowTTSConfig(output_path='/home/truc/Documents/ViTTS/tests/output/output_train', logger_uri=None, run_name='run', project_name=None, run_description='🐸Coqui trainer run.', print_step=25, plot_step=100, model_param_stats=False, wandb_entity=None, dashboard_logger='tensorboard', log_model_step=None, save_step=1000, save_n_checkpoints=5, save_checkpoints=True, save_all_best=False, save_best_after=10000, target_loss=None, print_eval=False, test_delay_epochs=-1, run_eval=True, distributed_backend='nccl', distributed_url='tcp://localhost:54321', mixed_precision=True, epochs=2, batch_size=32, eval_batch_size=16, grad_clip=5.0, scheduler_after_epoch=True, lr=0.001, optimizer='RAdam', optimizer_params={'betas': [0.9, 0.998], 'weight_decay': 1e-06}, lr_scheduler='NoamLR', lr_scheduler_params={'warmup_steps': 4000}, use_grad_scaler=False, cudnn_enable=True, cudnn_deterministic=False, cudnn_benchmark=False, training_seed=54321, model='glow_tts', num_loader_workers=0, num_eval_loader_workers=0, use_noise_augment=False, audio=BaseAudioConfig(fft_size=1024, win_length=1024, hop_length=256, frame_shift_ms=None, frame_length_ms=None, stft_pad_mode='reflect', sample_rate=22050, resample=False, preemphasis=0.0, ref_level_db=20, do_sound_norm=False, log_func='np.log10', do_trim_silence=True, trim_db=45, do_rms_norm=False, db_level=None, power=1.5, griffin_lim_iters=60, num_mels=80, mel_fmin=0.0, mel_fmax=None, spec_gain=20, do_amp_to_db_linear=True, do_amp_to_db_mel=True, pitch_fmax=640.0, pitch_fmin=0.0, signal_norm=True, min_level_db=-100, symmetric_norm=True, max_norm=4.0, clip_norm=True, stats_path=None), use_phonemes=False, phonemizer=None, phoneme_language=None, compute_input_seq_cache=False, text_cleaner='vi_cleaners', enable_eos_bos_chars=False, test_sentences_file='', phoneme_cache_path=None, characters=None, add_blank=False, batch_group_size=0, loss_masking=None, sort_by_audio_len=False, min_audio_len=1, max_audio_len=inf, min_text_len=1, max_text_len=inf, compute_f0=False, compute_linear_spec=False, precompute_num_workers=0, start_by_longest=False, datasets=[BaseDatasetConfig(name='vispeech', path='/home/truc/Documents/ViTTS/tests/data/vispeech', meta_file_train='metadata_dummy.csv', ignored_speakers=None, language='vi', meta_file_val='', meta_file_attn_mask='')], test_sentences=['Chào bạn Trực, rất hân hạnh được gặp bạn', 'Cuộc sống luôn có những niềm vui và nổi buồn', 'Bước tới đèo ngang bóng xuế tà, cỏ cây chen đá lá chen hoa', 'Bây giờ là 9:30', '20010 là bao nhiêu thế?'], eval_split_max_size=None, eval_split_size=0.01, use_speaker_weighted_sampler=False, speaker_weighted_sampler_alpha=1.0, use_language_weighted_sampler=False, language_weighted_sampler_alpha=1.0, use_length_weighted_sampler=False, length_weighted_sampler_alpha=1.0, num_chars=None, encoder_type='rel_pos_transformer', encoder_params={'kernel_size': 3, 'dropout_p': 0.1, 'num_layers': 6, 'num_heads': 2, 'hidden_channels_ffn': 768, 'input_length': None}, use_encoder_prenet=True, hidden_channels_enc=192, hidden_channels_dec=192, hidden_channels_dp=256, dropout_p_dp=0.1, dropout_p_dec=0.05, mean_only=True, out_channels=80, num_flow_blocks_dec=12, inference_noise_scale=0.0, kernel_size_dec=5, dilation_rate=1, num_block_layers=4, num_speakers=0, c_in_channels=0, num_splits=4, num_squeeze=2, sigmoid_scale=False, d_vector_dim=0, data_dep_init_steps=10, style_wav_for_test=None, length_scale=1.0, use_speaker_embedding=False, speakers_file=None, use_d_vector_file=False, d_vector_file=False, min_seq_len=3, max_seq_len=500, r=1)

# %%
config_glowtts.characters

# %%
from vitts.utils.audio import AudioProcessor

# %%
ap = AudioProcessor.init_from_config(config_glowtts, verbose= False)

# %%
ap.resample = True

# %%
ap

# %%
from vitts.components.vitts.utils.text.tokenizer import TTSTokenizer
tokenizer, config_glowtts = TTSTokenizer.init_from_config(config_glowtts)

# %%
config_glowtts
# Out:
# GlowTTSConfig(output_path='/home/truc/Documents/ViTTS/tests/output/output_train', logger_uri=None, run_name='run', project_name=None, run_description='🐸Coqui trainer run.', print_step=25, plot_step=100, model_param_stats=False, wandb_entity=None, dashboard_logger='tensorboard', log_model_step=None, save_step=1000, save_n_checkpoints=5, save_checkpoints=True, save_all_best=False, save_best_after=10000, target_loss=None, print_eval=False, test_delay_epochs=-1, run_eval=True, distributed_backend='nccl', distributed_url='tcp://localhost:54321', mixed_precision=True, epochs=2, batch_size=32, eval_batch_size=16, grad_clip=5.0, scheduler_after_epoch=True, lr=0.001, optimizer='RAdam', optimizer_params={'betas': [0.9, 0.998], 'weight_decay': 1e-06}, lr_scheduler='NoamLR', lr_scheduler_params={'warmup_steps': 4000}, use_grad_scaler=False, cudnn_enable=True, cudnn_deterministic=False, cudnn_benchmark=False, training_seed=54321, model='glow_tts', num_loader_workers=0, num_eval_loader_workers=0, use_noise_augment=False, audio=BaseAudioConfig(fft_size=1024, win_length=1024, hop_length=256, frame_shift_ms=None, frame_length_ms=None, stft_pad_mode='reflect', sample_rate=22050, resample=False, preemphasis=0.0, ref_level_db=20, do_sound_norm=False, log_func='np.log10', do_trim_silence=True, trim_db=45, do_rms_norm=False, db_level=None, power=1.5, griffin_lim_iters=60, num_mels=80, mel_fmin=0.0, mel_fmax=None, spec_gain=20, do_amp_to_db_linear=True, do_amp_to_db_mel=True, pitch_fmax=640.0, pitch_fmin=0.0, signal_norm=True, min_level_db=-100, symmetric_norm=True, max_norm=4.0, clip_norm=True, stats_path=None), use_phonemes=False, phonemizer=None, phoneme_language=None, compute_input_seq_cache=False, text_cleaner='vi_cleaners', enable_eos_bos_chars=False, test_sentences_file='', phoneme_cache_path=None, characters=CharactersConfig(characters_class='vitts.components.vitts.utils.text.characters.Graphemes', vocab_dict=None, pad='<PAD>', eos='<EOS>', bos='<BOS>', blank='<BLNK>', characters='abcdefghijklmnopqrstuvwxyzáàảãạăắằẳẵặâấầẩẫậéèẻẽẹêếềểễệóòỏõọôốồổỗộơớờởỡợíìỉĩịúùủũụưứừửữựýỳỷỹỵđ', punctuations="!'(),-.:;? ", phonemes=None, is_unique=False, is_sorted=True), add_blank=False, batch_group_size=0, loss_masking=None, sort_by_audio_len=False, min_audio_len=1, max_audio_len=inf, min_text_len=1, max_text_len=inf, compute_f0=False, compute_linear_spec=False, precompute_num_workers=0, start_by_longest=False, datasets=[BaseDatasetConfig(name='vispeech', path='/home/truc/Documents/ViTTS/tests/data/vispeech', meta_file_train='metadata_dummy.csv', ignored_speakers=None, language='vi', meta_file_val='', meta_file_attn_mask='')], test_sentences=['Chào bạn Trực, rất hân hạnh được gặp bạn', 'Cuộc sống luôn có những niềm vui và nổi buồn', 'Bước tới đèo ngang bóng xuế tà, cỏ cây chen đá lá chen hoa', 'Bây giờ là 9:30', '20010 là bao nhiêu thế?'], eval_split_max_size=None, eval_split_size=0.01, use_speaker_weighted_sampler=False, speaker_weighted_sampler_alpha=1.0, use_language_weighted_sampler=False, language_weighted_sampler_alpha=1.0, use_length_weighted_sampler=False, length_weighted_sampler_alpha=1.0, num_chars=None, encoder_type='rel_pos_transformer', encoder_params={'kernel_size': 3, 'dropout_p': 0.1, 'num_layers': 6, 'num_heads': 2, 'hidden_channels_ffn': 768, 'input_length': None}, use_encoder_prenet=True, hidden_channels_enc=192, hidden_channels_dec=192, hidden_channels_dp=256, dropout_p_dp=0.1, dropout_p_dec=0.05, mean_only=True, out_channels=80, num_flow_blocks_dec=12, inference_noise_scale=0.0, kernel_size_dec=5, dilation_rate=1, num_block_layers=4, num_speakers=0, c_in_channels=0, num_splits=4, num_squeeze=2, sigmoid_scale=False, d_vector_dim=0, data_dep_init_steps=10, style_wav_for_test=None, length_scale=1.0, use_speaker_embedding=False, speakers_file=None, use_d_vector_file=False, d_vector_file=False, min_seq_len=3, max_seq_len=500, r=1)

# %%
config_glowtts.characters
# Out:
# CharactersConfig(characters_class='vitts.components.vitts.utils.text.characters.Graphemes', vocab_dict=None, pad='<PAD>', eos='<EOS>', bos='<BOS>', blank='<BLNK>', characters='abcdefghijklmnopqrstuvwxyzáàảãạăắằẳẵặâấầẩẫậéèẻẽẹêếềểễệóòỏõọôốồổỗộơớờởỡợíìỉĩịúùủũụưứừửữựýỳỷỹỵđ', punctuations="!'(),-.:;? ", phonemes=None, is_unique=False, is_sorted=True)

# %%
from vitts.components.vitts.datasets import load_tts_samples

train_samples, eval_samples = load_tts_samples(
    dataset_config,
    eval_split= True,
    eval_split_size=0.2,
)
# Out:
#  | > Found 48 files in /home/truc/Documents/ViTTS/tests/data/vispeech

# %%
train_samples
# Out:
# [{'text': 'tiết kiêm nhiên liệu giảm khí thải ô nhiễm môi trường giữ sạch buồng đốt và các chi tiết bên trong động cơ\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/1/14914.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'kiên trì uống nước hạt ươi mỗi ngày có thể điều trị được bệnh gai cột sống\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/1/14916.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'kết quả nội soi ban đầu về khối u thanh quản phải của chị hoàng hà\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/0/09985.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'giới phân tích cho biết ngay cả hai nhà lãnh đạo quyền lực nhất trong quá khứ là ông mao trạch đông và ông đặng tiểu bình cũng không dám\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/0/09992.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'dạt né khôn gà miệng lông tốt từ ngoài vo trong chay chét\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/1/14932.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'cũng quyết định xả quỹ bình ổn giá để kiểm soát mức tăng giá xăng dầu trong nước\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/0/09986.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'thúy anh bất ngờ chia sẻ câu chuyện về việc cô bé đã thoát khỏi việc bị điếc phát triển bình thường nhờ tình cảm to lớn của mẹ\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/1/14909.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'nhanh như cắt anh nuôi hường cắp nách chiếc xẻng quân dụng chuyên dùng đảo cơm quên cả bỏng vồ lấy vung đậy kín chảo cơm tránh bụi\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/0/09984.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'trong đó vẫn có những truyện dài truyện chữ nhưng số lượng ít hơn để phục vụ học sinh có thiên hướng văn chương thưởng thức cô hiền nói\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/1/14915.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'tôi chưa có khát khao muốn trở thành mẹ lại càng không thích trông trẻ\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/1/14924.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'ca khúc gợi ý cách giáo dục trẻ của các mẹ nhật đáng tham khảo\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/1/14928.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'theo đó nam sinh duy nhất sẽ hóa thành cô dâu còn các bạn nữ sẽ là chú rể\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/1/14934.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'làm sạch với sữa rửa mặt để loại bỏ hết bụi bẩn bã nhờn của cả ngày tích tụ trên bề mặt da\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/1/14927.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'khi thử sản phẩm mới da ửng đỏ hay châm chích vội cho là sản phẩm kích ứng\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/0/09982.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'là những chuẩn mực mà người dân phố cổ hội an đang hướng đến\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/1/14922.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'công thức làm thịt thăn thịt sườn gác bếp chuẩn vị tây bắc\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/0/09981.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'nhưng nếu làm một nghề khác có lẽ tôi sẽ thích những chiếc xe đạp ông nói\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/1/14917.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'tình trạng này nếu kéo dài thường xuyên sẽ dẫn đến nhiễm trùng bộ phận sinh dục ở cả đàn ông và phụ nữ\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/1/14911.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'tùy vào từng loại da chị em có khả năng chọn lựa cho mình những sản phẩm phù hợp nhất\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/1/14919.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'của anh chúng ta sẽ có được những mảnh ghép phối kỳ lạ giữa hình ảnh một nhà trí thức tranh đấu và hình ảnh một nhà thơ siêu thực đúng nghĩa\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/1/14918.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'tôi chiều em yêu em và không dưới trăm lần ao ước rằng tôi chưa ràng buộc gì để có thể đường đường chính chính đến bên em\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/1/14913.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'sản xuất theo công nghệ sản xuất khép kín và độc quyền\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/0/09993.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'khóa học tụ họp phát triển các kỹ năng phần mềm đồ họa phục vụ công tác khai triển thiết kế nội thất\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/1/14920.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'họ nhịn ăn cơm và thay bằng hoa quả để giảm cân nhưng kết quả thì ngược lại với mong muốn\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/0/09994.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'hắn cho người bắt cóc con gái phan sơn làm con tin trao đổi\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/1/14906.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'và mọi người đang ráo riết hoàn thành khâu trang trí để kịp cho buổi tiệc diễn ra vài tiếng đồng hồ nữa\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/1/14907.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'cộng thêm với tình trạng béo phì thừa cân và ít vận động khiến tình trạng bệnh ngày thêm tăng nặng\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/0/09998.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'các cuộc đụng độ bạo lực giữa ngư dân trung quốc và các nhà chức trách hàn quốc đã khiến hàng chục người thiệt mạng\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/1/14923.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'mắt có thể nhỏ mắt bằng nước muối sinh lí nếu bội nhiễm thì nhỏ bằng kháng sinh\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/1/14926.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'hy vọng các bạn sẽ theo dõi chúng tôi thi đấu đó sẽ là những trận đấu hấp dẫn và đáng được chờ đợi\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/1/14925.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'người đứng đầu chính phủ quá sốt ruột khi tồn tại từ phiên họp trước vẫn còn đó\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/0/09997.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'lỡ lạc chân vào phòng ngủ của vợ cũ hồ quang hiếu thấy cảnh này đảm bảo ai cũng tim đập chân run\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/1/14933.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'với kiểu dáng đơn giản chiếc quần ống chạm đến mắt cá chân mang vẻ thanh lịch lại trẻ trung cho người mặc\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/1/14930.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'công ty của bạn có thể lãi lớn giúp bạn kiếm về hàng trăm nghìn usd một năm\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/1/14929.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'nguyên tác dạ cổ hoài lang ít nhân vật ít bối cảnh\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/0/09995.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'một lính kỵ binh trong triều đình nhà thanh ở hồ bắc\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/0/09991.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'làm lụng tiết kiệm cả đời để con được học hành đến nơi đến chốn và sống thoải mái no đủ\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/1/14912.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'thật là một hành trình khó khăn khi mọi người phải nhẹ nhàng lật các lớp lá lên săm soi thật kỹ xem có cây nấm nào đang ẩn nấp không\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/1/14908.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'},
#  {'text': 'phi nhung từng chia sẻ cô đã từng yêu và sống như vợ chồng với hai người đàn ông nhưng họ đều bỏ chị mà đi\n',
#   'audio_file': '/home/truc/Documents/ViTTS/tests/data/vispeech/wavs/0/09996.wav',
#   'speaker_name': 'vispeech',
#   'language': 'vi'}]

# %%
from vitts.components.vitts.models.glow_tts import GlowTTS

model = GlowTTS(
    config_glowtts,
    ap,
    tokenizer = tokenizer,
    speaker_manager= None
)

# %%
from trainer import Trainer, TrainerArgs

trainer = Trainer(
    TrainerArgs(),
    config_glowtts,
    output_path= OUT_PATH,
    model = model,
    train_samples= train_samples,
    eval_samples= eval_samples

)
# Out:
#  > Using CUDA: False
#  > Number of GPUs: 0
#
#  > Model has 28605841 parameters

# %%
# trainer.fit()

# %%
# from phonemizer.phonemize import phonemize

# %%
# text1 = ['một', 'chuyện', 'tình yêu']
# phn1 = phonemize(text1, language='vi', backend='espeak', strip=True)

# %%
from vitts.inference.synthesizer import Synthesizer

# %%
def test_in_out():
    tts_checkpoint = "/home/truc/Documents/ViTTS/tests/output/output_train/run-July-19-2022_10+33PM-56a0cb4/best_model.pth"
    tts_config = "/home/truc/Documents/ViTTS/tests/output/output_train/run-July-19-2022_10+33PM-56a0cb4/config.json"
    synthesizer = Synthesizer(tts_checkpoint, tts_config, None, None)
    wav = synthesizer.tts("Xin chào bạn em")
    synthesizer.save_wav(wav, "hihi.wav")

# %%
test_in_out()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_17534/3084345879.py in <module>
# ----> 1 test_in_out()
#
# /tmp/ipykernel_17534/792587022.py in test_in_out()
#       2     tts_checkpoint = "/home/truc/Documents/ViTTS/tests/output/output_train/run-July-19-2022_10+33PM-56a0cb4/best_model.pth"
#       3     tts_config = "/home/truc/Documents/ViTTS/tests/output/output_train/run-July-19-2022_10+33PM-56a0cb4/config.json"
# ----> 4     synthesizer = Synthesizer(tts_checkpoint, tts_config, None, None)
#       5     wav = synthesizer.tts("Xin chào bạn em")
#       6     synthesizer.save_wav(wav, "hihi.wav")
#
# ~/Documents/ViTTS/vitts/inference/synthesizer.py in __init__(self, tts_checkpoint, tts_config_path, tts_speakers_file, tts_languages_file, vocoder_checkpoint, vocoder_config, encoder_checkpoint, encoder_config, use_cuda)
#      72         if self.use_cuda:
#      73             assert torch.cuda.is_available(), "CUDA is not availabe on this machine."
# ---> 74         self._load_tts(tts_checkpoint, tts_config_path, use_cuda)
#      75         self.output_sample_rate = self.tts_config.audio["sample_rate"]
#      76         if vocoder_checkpoint:
#
# ~/Documents/ViTTS/vitts/inference/synthesizer.py in _load_tts(self, tts_checkpoint, tts_config_path, use_cuda)
#     105         """
#     106         # pylint: disable=global-statement
# --> 107         self.tts_config = load_config(tts_config_path)
#     108         if self.tts_config["use_phonemes"] and self.tts_config["phonemizer"] is None:
#     109             raise ValueError("Phonemizer is not defined in the TTS config.")
#
# ~/Documents/ViTTS/vitts/utils/config/__init__.py in load_config(config_path)
#      38         raise TypeError(f"! Unknown config type. Please use file yaml or json")
#      39     config_dict.update(data)
# ---> 40     model_name = _process_model_name(config_dict)
#      41     config_class = register_config(model_name.lower())
#      42     config = config_class()
#
# ~/Documents/ViTTS/vitts/utils/config/__init__.py in register_config(model_name)
#      80         except ModuleNotFoundError:
#      81             pass
# ---> 82     if config_class is None:
#      83         raise ModuleNotFoundError(f"! Config for {model_name} cannot be found.")
#      84     return config_class
#
# ModuleNotFoundError: ! Config for glow_tts cannot be found.
